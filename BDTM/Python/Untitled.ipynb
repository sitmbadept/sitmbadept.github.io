# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/sitmbadept/sitmbadept.github.io/main/BDTM/R/IPL.csv")

# %%
from pandasql import sqldf 
sqldf1 = lambda q: sqldf(q, globals())

# %%
sqldf1("select * from data")
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA  2.0      SA   KXIP   Allrounder     0.0     0.0
# 1         2  Abdur Razzak  2.0     BAN    RCB       Bowler   214.0    18.0
# 2         3   Agarkar, AB  2.0     IND    KKR       Bowler   571.0    58.0
# 3         4     Ashwin, R  1.0     IND    CSK       Bowler   284.0    31.0
# 4         5  Badrinath, S  2.0     IND    CSK      Batsman    63.0     0.0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 127     128  Yuvraj Singh  2.0     IND  KXIP+      Batsman  1775.0     9.0
# 128     129   Zaheer Khan  2.0     IND    MI+       Bowler  1114.0   288.0
# 129     130    Zoysa, DNT  2.0      SL     DC       Bowler   288.0    64.0
# 130     131         Dummy  NaN   Dummy  Dummy        Dummy     NaN     NaN
# 131     132         Dummy  NaN   Dummy  Dummy        Dummy     NaN     NaN
#
# ...

# %%
# Read File in Python
# View the structure of File
# Display all the column name
# Access column 
# Frequecy Count for Value
# View Data Types of Each Columns
# Unique Value
# Head
# Tail
# Shape

# %%
data.dtypes

# %%
data.describe(include='all')

# %%
data['COUNTRY'].unique()

# %%
data['COUNTRY'].value_counts()

# %%
data[['COUNTRY','TEAM']].drop_duplicates()

# %%
data.describe()

# %%
# !pip install pysqldf

# %%
from pysqldf import SQLDF
sqldf = SQLDF(globals())

# %%
sqldf.execute("Select * from data")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-73da14ae31e0> in <module>
# ----> 1 sqldf.execute("Select * from data")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pysqldf/sqldf.py in execute(self, query)
#      74             result = None
#      75         finally:
# ---> 76             self._del_table(tables)
#      77         return result
#      78
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pysqldf/sqldf.py in _del_table(self, tablenames)
#     115     def _del_table(self, tablenames):
#     116         for tablename in tablenames:
# --> 117             self.conn.execute("drop table " + tablename)
#     118         self.conn.commit()
#     119
#
# OperationalError: no such table: data

# %%
# !pip install -U pandasql
# Out:
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26818 sha256=92ac52814dbef949ca92d045d3f62145f7e58d9bb3e9c4af34e2124464b5dc44
#   Stored in directory: /Users/ankit.velani/Library/Caches/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# ...
